# %%
import os
import pandas as pd
import sodapy as Socrata

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
#client = Socrata("data.cityofchicago.org", None)

# Example authenticated client (needed for non-public datasets):
client = Socrata('data.cityofchicago.org',
                'OAtaZgqYsVBUqhl9a1bqe3Pzy',
                  username="username",
                  password="password")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("8pix-ypme", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df.head()
# Out:
#   stop_id direction_id                          stop_name  \
# 0   30162            W           18th (54th/Cermak-bound)
# 1   30161            E                  18th (Loop-bound)
# 2   30022            N           35th/Archer (Loop-bound)
# 3   30023            S         35th/Archer (Midway-bound)
# 4   30213            N  35-Bronzeville-IIT (Harlem-bound)
#
#            station_name           station_descriptive_name map_id   ada  \
# 0                  18th                   18th (Pink Line)  40830  True
# 1                  18th                   18th (Pink Line)  40830  True
# 2           35th/Archer          35th/Archer (Orange Line)  40120  True
# 3           35th/Archer          35th/Archer (Orange Line)  40120  True
# 4  35th-Bronzeville-IIT  35th-Bronzeville-IIT (Green Line)  41120  True
#
#      red   blue      g  ...      p      y    pnk      o  \
# 0  False  False  False  ...  False  False   True  False
# 1  False  False  False  ...  False  False   True  False
# 2  False  False  False  ...  False  False  False   True
# 3  False  False  False  ...  False  False  False   True
# 4  False  False   True  ...  False  False  False  False
#
#                                             location  \
# 0  {'latitude': '41.857908', 'longitude': '-87.66...
# 1  {'latitude': '41.857908', 'longitude': '-87.66...
# 2  {'latitude': '41.829353', 'longitude': '-87.68...
# 3  {'latitude': '41.829353', 'longitude': '-87.68...
# 4  {'latitude': '41.831677', 'longitude': '-87.62...
#
#   :@computed_region_awaf_s7ux :@computed_region_6mkv_f3dw  \
# 0                           8                       14920
# 1                           8                       14920
# 2                          26                       14924
# 3                          26                       14924
# 4                          12                       21194
#
#   :@computed_region_vrxf_vc4k :@computed_region_bdys_3d7i  \
# 0                          33                         343
# 1                          33                         343
# 2                          56                         719
# 3                          56                         719
# 4                           1                          25
#
#   :@computed_region_43wa_7qmu
# 0                          26
# 1                          26
# 2                           1
# 3                           1
# 4                           9
#
# [5 rows x 21 columns]

# %%
orange_stations=results_df[results_df['o']==True]
orange_stations
# Out:
#     stop_id direction_id                       stop_name  \
# 2     30022            N        35th/Archer (Loop-bound)
# 3     30023            S      35th/Archer (Midway-bound)
# 27    30132            S       Adams/Wabash (Inner Loop)
# 40    30206            S          Ashland (Midway-bound)
# 41    30205            N            Ashland (Loop-bound)
# 91    30074            E         Clark/Lake (Inner Loop)
# 142   30216            S          Halsted (Midway-bound)
# 143   30215            N            Halsted (Loop-bound)
# 151   30166            W       H.W. Library (Inner Loop)
# 174   30219            N             Kedzie (Loop-bound)
# 177   30220            S           Kedzie (Midway-bound)
# 197   30031            W  LaSalle/Van Buren (Inner Loop)
# 210   30182            S                Midway (Arrival)
# 211   30181            N             Midway (Loop-bound)
# 243   30186            S          Pulaski (Midway-bound)
# 245   30185            N            Pulaski (Loop-bound)
# 248   30007            N       Quincy/Wells (Inner Loop)
# 257   30081            S   Roosevelt (Midway-63rd-bound)
# 258   30080            N   Roosevelt (Loop-Harlem-bound)
# 274   30050            E         State/Lake (Inner Loop)
# 282   30384            S  Washington/Wabash (Inner Loop)
# 285   30141            N   Washington/Wells (Inner Loop)
# 291   30061            S          Western (Midway-bound)
# 294   30060            N            Western (Loop-bound)
#
#                                   station_name  \
# 2                                  35th/Archer
# 3                                  35th/Archer
# 27                                Adams/Wabash
# 40                                     Ashland
# 41                                     Ashland
# 91                                  Clark/Lake
# 142                                    Halsted
# 143                                    Halsted
# 151  Harold Washington Library-State/Van Buren
# 174                                     Kedzie
# 177                                     Kedzie
# 197                          LaSalle/Van Buren
# 210                                     Midway
# 211                                     Midway
# 243                                    Pulaski
# 245                                    Pulaski
# 248                               Quincy/Wells
# 257                                  Roosevelt
# 258                                  Roosevelt
# 274                                 State/Lake
# 282                          Washington/Wabash
# 285                           Washington/Wells
# 291                                    Western
# 294                                    Western
#
#                               station_descriptive_name map_id    ada    red  \
# 2                            35th/Archer (Orange Line)  40120   True  False
# 3                            35th/Archer (Orange Line)  40120   True  False
# 27   Adams/Wabash (Brown, Green, Orange, Pink & Pur...  40680  False  False
# 40                               Ashland (Orange Line)  41060   True  False
# 41                               Ashland (Orange Line)  41060   True  False
# 91   Clark/Lake (Blue, Brown, Green, Orange, Purple...  40380   True  False
# 142                              Halsted (Orange Line)  41130   True  False
# 143                              Halsted (Orange Line)  41130   True  False
# 151  Harold Washington Library-State/Van Buren (Bro...  40850   True  False
# 174                               Kedzie (Orange Line)  41150   True  False
# 177                               Kedzie (Orange Line)  41150   True  False
# 197  LaSalle/Van Buren (Brown, Orange, Purple & Pin...  40160  False  False
# 210                               Midway (Orange Line)  40930   True  False
# 211                               Midway (Orange Line)  40930   True  False
# 243                              Pulaski (Orange Line)  40960   True  False
# 245                              Pulaski (Orange Line)  40960   True  False
# 248  Quincy/Wells (Brown, Orange, Purple & Pink lines)  40040   True  False
# 257              Roosevelt (Red, Orange & Green lines)  41400   True  False
# 258              Roosevelt (Red, Orange & Green lines)  41400   True  False
# 274  State/Lake (Brown, Green, Orange, Pink & Purpl...  40260  False  False
# 282  Washington/Wabash (Brown, Green, Orange, Purpl...  41700   True  False
# 285  Washington/Wells (Brown, Orange, Purple & Pink...  40730   True  False
# 291                              Western (Orange Line)  40310   True  False
# 294                              Western (Orange Line)  40310   True  False
#
#       blue      g  ...      p      y    pnk     o  \
# 2    False  False  ...  False  False  False  True
# 3    False  False  ...  False  False  False  True
# 27   False   True  ...   True  False   True  True
# 40   False  False  ...  False  False  False  True
# 41   False  False  ...  False  False  False  True
# 91   False   True  ...   True  False   True  True
# 142  False  False  ...  False  False  False  True
# 143  False  False  ...  False  False  False  True
# 151  False  False  ...   True  False   True  True
# 174  False  False  ...  False  False  False  True
# 177  False  False  ...  False  False  False  True
# 197  False  False  ...   True  False   True  True
# 210  False  False  ...  False  False  False  True
# 211  False  False  ...  False  False  False  True
# 243  False  False  ...  False  False  False  True
# 245  False  False  ...  False  False  False  True
# 248  False  False  ...   True  False   True  True
# 257  False   True  ...  False  False  False  True
# 258  False   True  ...  False  False  False  True
# 274  False   True  ...   True  False   True  True
# 282  False   True  ...   True  False   True  True
# 285  False  False  ...   True  False   True  True
# 291  False  False  ...  False  False  False  True
# 294  False  False  ...  False  False  False  True
#
#                                               location  \
# 2    {'latitude': '41.829353', 'longitude': '-87.68...
# 3    {'latitude': '41.829353', 'longitude': '-87.68...
# 27   {'latitude': '41.879507', 'longitude': '-87.62...
# 40   {'latitude': '41.839234', 'longitude': '-87.66...
# 41   {'latitude': '41.839234', 'longitude': '-87.66...
# 91   {'latitude': '41.885737', 'longitude': '-87.63...
# 142  {'latitude': '41.84678', 'longitude': '-87.648...
# 143  {'latitude': '41.84678', 'longitude': '-87.648...
# 151  {'latitude': '41.876862', 'longitude': '-87.62...
# 174  {'latitude': '41.804236', 'longitude': '-87.70...
# 177  {'latitude': '41.804236', 'longitude': '-87.70...
# 197  {'latitude': '41.8768', 'longitude': '-87.6317...
# 210  {'latitude': '41.78661', 'longitude': '-87.737...
# 211  {'latitude': '41.78661', 'longitude': '-87.737...
# 243  {'latitude': '41.799756', 'longitude': '-87.72...
# 245  {'latitude': '41.799756', 'longitude': '-87.72...
# 248  {'latitude': '41.878723', 'longitude': '-87.63...
# 257  {'latitude': '41.867405', 'longitude': '-87.62...
# 258  {'latitude': '41.867405', 'longitude': '-87.62...
# 274  {'latitude': '41.88574', 'longitude': '-87.627...
# 282  {'latitude': '41.88322', 'longitude': '-87.626...
# 285  {'latitude': '41.882695', 'longitude': '-87.63...
# 291  {'latitude': '41.804546', 'longitude': '-87.68...
# 294  {'latitude': '41.804546', 'longitude': '-87.68...
#
#     :@computed_region_awaf_s7ux :@computed_region_6mkv_f3dw  \
# 2                            26                       14924
# 3                            26                       14924
# 27                           22                       14912
# 40                           26                       14920
# 41                           26                       14920
# 91                           22                       14309
# 142                          26                       14920
# 143                          26                       14920
# 151                          48                       14913
# 174                          49                       22248
# 177                          49                       22248
# 197                          48                       14913
# 210                          35                       21867
# 211                          35                       21867
# 243                          35                       22248
# 245                          35                       22248
# 248                          22                       14912
# 257                          48                       14913
# 258                          48                       14913
# 274                          22                       14309
# 282                          22                       14310
# 285                          22                       14310
# 291                          19                       14924
# 294                          19                       14924
#
#     :@computed_region_vrxf_vc4k :@computed_region_bdys_3d7i  \
# 2                            56                         719
# 3                            56                         719
# 27                           38                         367
# 40                           33                         126
# 41                           33                         126
# 91                           38                          92
# 142                          58                          59
# 143                          58                          59
# 151                          38                          92
# 174                          55                         776
# 177                          55                         776
# 197                          38                          92
# 210                          53                          86
# 211                          53                          86
# 243                          60                         793
# 245                          60                         793
# 248                          38                          92
# 257                          34                         374
# 258                          34                         374
# 274                          38                         580
# 282                          38                         580
# 285                          38                          92
# 291                          61                         775
# 294                          61                         775
#
#     :@computed_region_43wa_7qmu
# 2                             1
# 3                             1
# 27                           36
# 40                           26
# 41                           26
# 91                           36
# 142                          48
# 143                          48
# 151                          10
# 174                           8
# 177                           8
# 197                          10
# 210                          15
# 211                          15
# 243                           6
# 245                           6
# 248                          36
# 257                           9
# 258                           9
# 274                          36
# 282                          36
# 285                          36
# 291                           3
# 294                           3
#
# [24 rows x 21 columns]

# %%
#get subset of orange line stations
orange_stations=results_df[results_df['o']==True]
orange_stations['stop_id'].unique()
# Out:
# array(['30022', '30023', '30132', '30206', '30205', '30074', '30216',
#        '30215', '30166', '30219', '30220', '30031', '30182', '30181',
#        '30186', '30185', '30007', '30081', '30080', '30050', '30384',
#        '30141', '30061', '30060'], dtype=object)

# %%
#get subset of orange line stations
orange_stations=results_df[results_df['o']==True]
orange_stations['station_name'].unique()
# Out:
# array(['35th/Archer', 'Adams/Wabash', 'Ashland', 'Clark/Lake', 'Halsted',
#        'Harold Washington Library-State/Van Buren', 'Kedzie',
#        'LaSalle/Van Buren', 'Midway', 'Pulaski', 'Quincy/Wells',
#        'Roosevelt', 'State/Lake', 'Washington/Wabash', 'Washington/Wells',
#        'Western'], dtype=object)

# %%
#get subset of orange line stations
orange_stations=results_df[results_df['o']==True]
orange_stations['map_id'].unique()
# Out:
# array(['40120', '40680', '41060', '40380', '41130', '40850', '41150',
#        '40160', '40930', '40960', '40040', '41400', '40260', '41700',
#        '40730', '40310'], dtype=object)
